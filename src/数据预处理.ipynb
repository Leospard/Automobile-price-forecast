# %% [markdown]
# # 数据预处理

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style("whitegrid")
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False   #这两行需要手动设置

# %% [markdown]
# ## 数据读取

# %%
data = pd.read_csv("../data/whole_car.csv")

# %%
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ## 整体描述

# %%
# 数据量
data.shape
# Out:
# (104175, 20)

# %%
# 数据列
data.columns
# Out:
# Index(['Brand', 'Series', 'CarName', 'Province', 'City', 'Miles', 'Date',
#        '二手车报价', '新车厂商指导价', '级别', '能源类型', '环保标准', '上市时间', '最大功率(kW)',
#        '最大扭矩(N・m)', '发动机', '变速箱', '长*宽*高(mm)', '车身结构', 'NEDC综合油耗(L/100km)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104175 entries, 0 to 104174
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Brand              104175 non-null  object
#  1   Series             104175 non-null  object
#  2   CarName            104175 non-null  object
#  3   Province           104175 non-null  object
#  4   City               104175 non-null  object
#  5   Miles              104175 non-null  float64
#  6   Date               104175 non-null  object
#  7   二手车报价              104175 non-null  float64
#  8   新车厂商指导价            104175 non-null  object
#  9   级别                 104175 non-null  object
#  10  能源类型               104175 non-null  object
#  11  环保标准               104175 non-null  object
#  12  上市时间               104175 non-null  float64
#  13  最大功率(kW)           104175 non-null  object
#  14  最大扭矩(N・m)          104175 non-null  object
# ...

# %%
data.describe().columns
# Out:
# Index(['Miles', '二手车报价', '上市时间', 'Brand_label', 'Series_label',
#        'CarName_label', 'Province_label', 'City_label', 'Miles_std', 'CarAge',
#        'CarAge_std', 'Price_NewCar', 'Price_NewCar_std', 'Level_label', 'isEV',
#        'isICE', 'PollutionType', 'MarketTime', 'MaxPower', 'MaxTorque',
#        'Displacement', 'size_l', 'size_w', 'size_h', 'Doors', 'Seats', 'Oil'],
#       dtype='object')

# %% [markdown]
# ## 按列处理

# %% [markdown]
# ### Brand

# %% [markdown]
# #### 查看

# %%
# 品牌数据统计
brand_counts = data["Brand"].value_counts()
brand_counts
# Out:
# 宝马      13670
# 奔驰      13064
# 奥迪      10626
# 大众       8315
# 丰田       6112
#         ...
# 大乘汽车        1
# 比速汽车        1
# 新凯          1
# 君马汽车        1
# 卡升          1
# Name: Brand, Length: 135, dtype: int64

# %%
# 品牌数据描述
brand_counts.describe()
# Out:
# count      135.000000
# mean       771.666667
# std       2139.346211
# min          1.000000
# 25%          7.500000
# 50%         71.000000
# 75%        410.500000
# max      13670.000000
# Name: Brand, dtype: float64

# %%
# 按品牌对应数据的数量取品牌
brand_counts[brand_counts > 1000]
# Out:
# 宝马      13670
# 奔驰      13064
# 奥迪      10626
# 大众       8315
# 丰田       6112
# 本田       4781
# 别克       4491
# 保时捷      4452
# 路虎       2989
# 福特       2781
# 日产       2732
# 凯迪拉克     2159
# 雷克萨斯     2158
# MINI     1720
# 现代       1628
# 马自达      1430
# 雪佛兰      1221
# 吉利汽车     1141
# 沃尔沃      1067
# Name: Brand, dtype: int64

# %% [markdown]
# #### 编码

# %%
from sklearn.preprocessing import LabelEncoder
le_Brand = LabelEncoder()
data['Brand_label'] = le_Brand.fit_transform(data['Brand'])
# 通过le.inverse_transform([1])可以获得指定编码对应的品牌，即逆编码
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### Series

# %% [markdown]
# #### 查看

# %%
series_counts = data["Series"].value_counts()
series_counts
# Out:
# 宝马5系                 3255
# 宝马3系                 2729
# 奥迪A6L                2484
# 奥迪A4L                2319
# 别克GL8                2071
#                      ...
# 哈弗赤兔                    1
# 迈凯伦625C                 1
# 上汽大通MAXUS D60           1
# 上汽大通MAXUS EUNIQ 5       1
# MASTER CEO              1
# Name: Series, Length: 1259, dtype: int64

# %%
# 车系信息描述
series_counts.describe()
# Out:
# count    1259.000000
# mean       82.744241
# std       231.086226
# min         1.000000
# 25%         4.000000
# 50%        14.000000
# 75%        58.000000
# max      3255.000000
# Name: Series, dtype: float64

# %%
# 按车系对应数据的数量取车系
series_counts[series_counts > 500]
# Out:
# 宝马5系         3255
# 宝马3系         2729
# 奥迪A6L        2484
# 奥迪A4L        2319
# 别克GL8        2071
# 奔驰E级         1995
# 奔驰C级         1911
# Cayenne      1176
# 宝马X5(进口)     1105
# MINI         1095
# 奔驰GLC        1050
# 宝马7系         1026
# Panamera      997
# Macan         981
# 奔驰S级          960
# 凯美瑞           944
# 汉兰达           907
# 雅阁            872
# 雷克萨斯ES        838
# 高尔夫           833
# 宝马X1          832
# 奥迪A3          793
# 奥迪Q5          776
# 迈腾            767
# 凯迪拉克ATS-L     743
# 奔驰GLA         729
# 奥迪Q3          717
# 揽胜            665
# 思域            665
# 福克斯           645
# 揽胜运动版         625
# 奥德赛           622
# 天籁            576
# 奥迪Q7          550
# 君威            546
# 奥迪A8          544
# 发现            539
# 帕萨特           533
# 奥迪A5          532
# Polo          530
# 一汽-大众CC       528
# 保时捷718        519
# Name: Series, dtype: int64

# %% [markdown]
# #### 编码

# %%
from sklearn.preprocessing import LabelEncoder
le_Series = LabelEncoder()
data['Series_label'] = le_Series.fit_transform(data['Series'])
# 通过le.inverse_transform([1])可以获得指定编码对应的品牌，即逆编码
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### CarName

# %% [markdown]
# #### 查看

# %%
carname_counts = data["CarName"].value_counts()
carname_counts
# Out:
# 宝马5系 2014款 525Li 豪华设计套装                451
# 凯迪拉克ATS-L 2017款 28T 技术型                321
# 宝马5系 2014款 520Li 典雅型                   276
# Macan 2018款 Macan 2.0T                 260
# Cayenne 2011款 Cayenne 3.0T             241
#                                       ...
# 雷凌 2018款 185T CVT尊贵版 国VI                 1
# SAVANA 2012款 6.0L 皇家级                    1
# 启辰M50V 2017款 1.6L XL CVT豪华版              1
# 佳乐 2013款 2.0L 5座自动舒适版 国IV                1
# 索兰托 2016款 索兰托L 2.4L 汽油4WD定制版 7座 国IV      1
# Name: CarName, Length: 14095, dtype: int64

# %%
# 信息描述
carname_counts.describe()
# Out:
# count    14095.000000
# mean         7.390919
# std         15.205727
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          7.000000
# max        451.000000
# Name: CarName, dtype: float64

# %% [markdown]
# #### 编码

# %%
from sklearn.preprocessing import LabelEncoder
le_CarName = LabelEncoder()
data['CarName_label'] = le_CarName.fit_transform(data['CarName'])
# 通过le.inverse_transform([1])可以获得指定编码对应的车名，即逆编码
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### Province

# %% [markdown]
# #### 查看

# %%
province_counts = data["Province"].value_counts()
province_counts
# Out:
# 广东     12559
# 浙江     11790
# 江苏      7803
# 山东      5689
# 上海      5037
# 重庆      4655
# 湖北      4636
# 四川      4612
# 河南      4583
# 河北      4466
# 安徽      4363
# 广西      4346
# 湖南      4276
# 北京      4201
# 辽宁      4173
# 陕西      3538
# 云南      3329
# 贵州      2181
# 山西      2101
# 天津      1796
# 吉林      1421
# 黑龙江     1374
# 新疆      1147
# 福建        60
# 甘肃        12
# 江西        11
# 海南        10
# 宁夏         4
# 内蒙古        2
# Name: Province, dtype: int64

# %%
# 省份信息描述
province_counts.describe()
# Out:
# count       29.000000
# mean      3592.241379
# std       3156.669862
# min          2.000000
# 25%       1374.000000
# 50%       4173.000000
# 75%       4612.000000
# max      12559.000000
# Name: Province, dtype: float64

# %% [markdown]
# #### 编码

# %%
# 按省份对应数据的数量取车系
province_counts[province_counts > 1000]
from sklearn.preprocessing import LabelEncoder
le_Province = LabelEncoder()
data['Province_label'] = le_Province.fit_transform(data['Province'])
# 通过le.inverse_transform([1])可以获得逆编码
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### City

# %% [markdown]
# #### 查看

# %%
city_counts = data["City"].value_counts()
city_counts
# Out:
# 南京     5497
# 上海     5037
# 重庆     4655
# 武汉     4633
# 成都     4605
#        ...
# 河源        1
# 梅州        1
# 菏泽        1
# 白银        1
# 张家口       1
# Name: City, Length: 141, dtype: int64

# %%
# 信息描述
city_counts.describe()
# Out:
# count     141.000000
# mean      738.829787
# std      1545.797150
# min         1.000000
# 25%         1.000000
# 50%         4.000000
# 75%        20.000000
# max      5497.000000
# Name: City, dtype: float64

# %%
# 按车系对应数据的数量取车系
city_counts[city_counts > 1000]
# Out:
# 南京      5497
# 上海      5037
# 重庆      4655
# 武汉      4633
# 成都      4605
# 郑州      4567
# 石家庄     4424
# 合肥      4353
# 南宁      4332
# 深圳      4324
# 长沙      4269
# 东莞      4240
# 北京      4201
# 沈阳      4146
# 宁波      4038
# 广州      3941
# 杭州      3868
# 温州      3785
# 西安      3515
# 济南      3466
# 昆明      3316
# 苏州      2249
# 贵阳      2174
# 青岛      2148
# 太原      2089
# 天津      1796
# 长春      1420
# 哈尔滨     1368
# 乌鲁木齐    1147
# Name: City, dtype: int64

# %% [markdown]
# #### 编码

# %%
from sklearn.preprocessing import LabelEncoder
le_City = LabelEncoder()
data['City_label'] = le_City.fit_transform(data['City'])
# 通过le.inverse_transform([1])可以获得指定编码对应的车名，即逆编码
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### Miles

# %% [markdown]
# #### 查看

# %%
data["Miles"].describe()
# Out:
# count    104175.000000
# mean          6.498492
# std           4.079644
# min           0.010000
# 25%           3.300000
# 50%           6.000000
# 75%           9.000000
# max          46.800000
# Name: Miles, dtype: float64

# %% [markdown]
# #### 作图

# %%
data.corr()
# Out:
#                    Miles     二手车报价      上市时间  Brand_label  Series_label  \
# Miles           1.000000 -0.232194 -0.741998     0.004070      0.049697
# 二手车报价          -0.232194  1.000000  0.214513    -0.037442     -0.102984
# 上市时间           -0.741998  0.214513  1.000000     0.002284     -0.038191
# Brand_label     0.004070 -0.037442  0.002284     1.000000      0.537050
# Series_label    0.049697 -0.102984 -0.038191     0.537050      1.000000
# CarName_label   0.052365 -0.098379 -0.043274     0.533095      0.996742
# Province_label -0.005515 -0.093950  0.021577     0.028500      0.035102
# City_label     -0.030301 -0.064904  0.055631     0.012695      0.015897
#
#                 CarName_label  Province_label  City_label
# Miles                0.052365       -0.005515   -0.030301
# 二手车报价               -0.098379       -0.093950   -0.064904
# 上市时间                -0.043274        0.021577    0.055631
# Brand_label          0.533095        0.028500    0.012695
# ...

# %% [markdown]
# #### 标准化
#
# * 如何选择数据标准化的方法？
# * 这里用标准正态做标准化

# %%
from sklearn.preprocessing import StandardScaler
scaler_Miles = StandardScaler()
data['Miles_std'] = scaler_Miles.fit_transform(data['Miles'].values.reshape(-1, 1))
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %%
data['Miles_std'].describe()
# Out:
# count    1.041750e+05
# mean    -3.066283e-16
# std      1.000005e+00
# min     -1.590463e+00
# 25%     -7.840162e-01
# 50%     -1.221906e-01
# 75%      6.131711e-01
# max      9.878729e+00
# Name: Miles_std, dtype: float64

# %% [markdown]
# ### Date

# %% [markdown]
# #### 查看

# %%
data["Date"]
# Out:
# 0         19-Aug
# 1         14-Dec
# 2         18-Feb
# 3         14-Oct
# 4         19-Dec
#            ...
# 104170    16-Apr
# 104171    18-Jul
# 104172    20-Mar
# 104173    18-Jan
# 104174    14-Sep
# Name: Date, Length: 104175, dtype: object

# %%
data["Date"].describe()
# Out:
# count     104175
# unique       186
# top       19-Jan
# freq        2047
# Name: Date, dtype: object

# %% [markdown]
# #### 计算车龄CarAge

# %%
month_list = {"Jan": 1, "Feb": 2, "Mar": 3, "Apr": 4, "May": 5, "Jun": 6, "Jul": 7, "Aug": 8, "Sep": 9, "Oct": 10, "Nov": 11, "Dec": 12}

# %%
import re
def calMonths(dt, year = 22, month = 1):
    """
    根据三种格式的数据计算车龄（月）
    """
    if (dt == "未上牌"):
        return 0
    temp = dt.split('-')
    if (re.match(r".*[a-zA-Z]$", dt)):
        return 12*(year - int(temp[0])) + (month - month_list[temp[1]])
    elif (re.match(r"^[a-zA-Z]", dt)):
        return 12*(year - int(temp[1])) + (month - month_list[temp[0]])
    else:
        return 12*(2022 - int(temp[0])) + (month - int(temp[1]))

# %%
data["CarAge"] = data["Date"].apply(calMonths)
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# #### 车龄标准化

# %%
from sklearn.preprocessing import StandardScaler
scaler_CarAge = StandardScaler()
data['CarAge_std'] = scaler_CarAge.fit_transform(data['CarAge'].values.reshape(-1, 1))
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### 二手车报价

# %% [markdown]
# #### 查看

# %%
data['二手车报价'].describe()
# Out:
# count    104175.000000
# mean         29.951989
# std          48.711817
# min           0.480000
# 25%           9.800000
# 50%          17.980000
# 75%          32.800000
# max        3350.000000
# Name: 二手车报价, dtype: float64

# %% [markdown]
# #### 作图

# %%
# 初步作图，离群值影响严重
sns.histplot(data["二手车报价"])
# Out:
# <AxesSubplot:xlabel='二手车报价', ylabel='Count'>

# %%
# 如果取前95%的数据
sns.histplot(data["二手车报价"][data["二手车报价"] < data["二手车报价"].quantile(0.95)])
# Out:
# <AxesSubplot:xlabel='二手车报价', ylabel='Count'>

# %% [markdown]
# ### 新车厂商指导价

# %% [markdown]
# #### 查看

# %%
data['新车厂商指导价']
# Out:
# 0         149.08万
# 1          35.46万
# 2          42.76万
# 3          31.28万
# 4         109.80万
#            ...
# 104170     11.68万
# 104171     11.98万
# 104172    139.88万
# 104173     44.99万
# 104174     35.88万
# Name: 新车厂商指导价, Length: 104175, dtype: object

# %% [markdown]
# #### 提取数值Price_NewCar

# %%
data["Price_NewCar"] = data['新车厂商指导价'].apply(lambda x: float(x.split("万")[0]))
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# #### 作图

# %%
# 初步作图，离群值影响严重
sns.histplot(data["Price_NewCar"])
# Out:
# <AxesSubplot:xlabel='Price_NewCar', ylabel='Count'>

# %%
# 如果取前95%的数据
sns.histplot(data["Price_NewCar"][data["Price_NewCar"] < data["Price_NewCar"].quantile(0.95)])
# Out:
# <AxesSubplot:xlabel='Price_NewCar', ylabel='Count'>

# %% [markdown]
# #### 标准化Price_NewCar

# %%
from sklearn.preprocessing import StandardScaler
scaler_Price_NewCar = StandardScaler()
data['Price_NewCar_std'] = scaler_Price_NewCar.fit_transform(data['Price_NewCar'].values.reshape(-1, 1))
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %%
data['Price_NewCar_std'].describe()
# Out:
# count    1.041750e+05
# mean    -9.186252e-16
# std      1.000005e+00
# min     -8.359403e-01
# 25%     -4.924382e-01
# 50%     -2.691087e-01
# 75%      4.957903e-02
# max      4.613416e+01
# Name: Price_NewCar_std, dtype: float64

# %% [markdown]
# ### 级别

# %% [markdown]
# #### 查看

# %%
data['级别']
# Out:
# 0           大型车
# 1           中型车
# 2         中型SUV
# 3           中型车
# 4           大型车
#           ...
# 104170      微型车
# 104171     紧凑型车
# 104172      大型车
# 104173     中大型车
# 104174      中型车
# Name: 级别, Length: 104175, dtype: object

# %%
data['级别'].value_counts()
# Out:
# 中型车       20293
# 紧凑型车      15855
# 中大型车      12654
# 中型SUV     11710
# 紧凑型SUV    10577
# 中大型SUV    10109
# 大型车        4717
# 中大型MPV     4602
# 跑车         3723
# 小型车        3605
# 小型SUV      1829
# 中型MPV      1466
# 大型SUV      1096
# 紧凑型MPV      840
# 微型车         691
# 皮卡          248
# 大型MPV       160
# Name: 级别, dtype: int64

# %% [markdown]
# #### 编码

# %%
from sklearn.preprocessing import LabelEncoder
le_Level = LabelEncoder()
data['Level_label'] = le_Level.fit_transform(data['级别'])
# 通过le.inverse_transform([1])可以获得指定编码对应的车名，即逆编码
# le_Level.classes_查看编码的原始信息
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### 能源类型

# %% [markdown]
# #### 查看

# %%
data['能源类型']
# Out:
# 0         汽油
# 1         汽油
# 2         汽油
# 3         汽油
# 4         汽油
#           ..
# 104170    汽油
# 104171    汽油
# 104172    汽油
# 104173    汽油
# 104174    汽油
# Name: 能源类型, Length: 104175, dtype: object

# %%
data['能源类型'].value_counts()
# Out:
# 汽油            97933
# 汽油+48V轻混系统     2724
# 油电混合           1664
# 插电式混合动力        1171
# 柴油              558
# 增程式             107
# 汽油+90V轻混系统       18
# Name: 能源类型, dtype: int64

# %% [markdown]
# 不同能源类型的样本数量相差较大，而其中汽油、柴油、汽油+48V清混系统、汽油+90V清混系统都属于传统燃油车

# %% [markdown]
# #### 合并近似类型

# %%
def getEnergyType(EnergyType):
    if (EnergyType.startswith("汽油") or EnergyType == "柴油"):
        return "ICE" # 燃油车
    elif (EnergyType == "油电混合" or EnergyType == "插电式混合动力" or EnergyType == "增程式"):
        return "EV" # 新能源车
    else:
        return None

# %%
data["EnergyType"] = data['能源类型'].apply(getEnergyType)
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# #### LabelEncoder

# %%
# # 暂时使用独热编码
# from sklearn.preprocessing import LabelEncoder
# le_EnergyType = LabelEncoder()
# data['EnergyType_label'] = le_EnergyType.fit_transform(data['EnergyType'])
# # 通过le.inverse_transform([1])可以获得指定编码对应的车名，即逆编码
# # le_Level.classes_查看编码的原始信息
# data

# %% [markdown]
# #### OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder
oe_EnergyType = OneHotEncoder()
temp = pd.DataFrame(oe_EnergyType.fit_transform(data['EnergyType'].values.reshape(-1, 1)).toarray(), columns=["isEV", "isICE"])
data = pd.concat([data, temp], axis=1)
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### 环保标准

# %% [markdown]
# #### 查看

# %%
data['环保标准'].value_counts()
# Out:
# 国V             28578
# 国VI            23395
# 国IV(国V)        18970
# 欧V             13879
# 欧IV             9645
# 国IV             3551
# 国IV+OBD         2104
# 欧VI             2054
# 欧IV+OBD         1113
# 国V+OBD           450
# 国V(国VI)          165
# 欧V+OBD           155
# 国IV(国V)+OBD       52
# 国III              37
# 欧III              21
# 国III+OBD           6
# Name: 环保标准, dtype: int64

# %% [markdown]
# 排放标准数据合并相同的，分为 3 4 5 6 4种

# %% [markdown]
# #### 合并近似类型

# %%
def getPollutionType(s):
    if (s.startswith("国V(国VI)") or s.startswith("国VI") or s.startswith("欧VI")):
        return 6
    elif (s.startswith("国IV(国V)") or s.startswith("国V") or s.startswith("欧V")):
        return 5
    elif (s.startswith("国IV") or s.startswith("欧IV")):
        return 4
    elif (s.startswith("国III") or s.startswith("欧III")):
        return 3
    else:
        return None

# %%
data["PollutionType"] = data['环保标准'].apply(getPollutionType)
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %%
data['PollutionType'].value_counts()
# Out:
# 5    62084
# 6    25614
# 4    16413
# 3       64
# Name: PollutionType, dtype: int64

# %% [markdown]
# ### 上市时间

# %% [markdown]
# #### 查看

# %%
data['上市时间'].value_counts()
# Out:
# 2016.09    1899
# 2013.09    1732
# 2020.09    1681
# 2017.11    1679
# 2018.10    1553
#            ...
# 2007.05       4
# 2022.01       2
# 2006.12       1
# 2006.08       1
# 2007.04       1
# Name: 上市时间, Length: 178, dtype: int64

# %% [markdown]
# #### 提取上市时长

# %%
def getMarketTime(s):
    year = int(s)
    month = (s - year)*100
    return 12*(2022-year)+(1-month)

# %%
data["MarketTime"] = data['上市时间'].apply(getMarketTime)
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %%
data["MarketTime"].describe()
# Out:
# count    1.041750e+05
# mean     7.162118e+01
# std      3.739851e+01
# min      9.094947e-13
# 25%      4.100000e+01
# 50%      6.700000e+01
# 75%      1.000000e+02
# max      1.870000e+02
# Name: MarketTime, dtype: float64

# %% [markdown]
# ### 最大功率(kW)

# %% [markdown]
# #### 查看

# %%
data["最大功率(kW)"]
# Out:
# 0          257
# 1          135
# 2          169
# 3          132
# 4          250
#           ...
# 104170      52
# 104171    95.3
# 104172     270
# 104173     165
# 104174     135
# Name: 最大功率(kW), Length: 104175, dtype: object

# %% [markdown]
# #### 转浮点数

# %%
data["MaxPower"] = data["最大功率(kW)"].apply(lambda x: None if x == '-' else float(x))

# %%
data["MaxPower"].describe()
# Out:
# count    103824.000000
# mean        158.390067
# std          67.541307
# min          33.500000
# 25%         115.000000
# 50%         140.000000
# 75%         185.000000
# max         850.000000
# Name: MaxPower, dtype: float64

# %% [markdown]
# ### 最大扭矩(N・m)

# %% [markdown]
# #### 查看

# %%
data["最大扭矩(N・m)"]
# Out:
# 0         500
# 1         270
# 2         350
# 3         320
# 4         500
#          ...
# 104170     91
# 104171    157
# 104172    500
# 104173    310
# 104174    270
# Name: 最大扭矩(N・m), Length: 104175, dtype: object

# %% [markdown]
# #### 转浮点数

# %%
data["MaxTorque"] = data["最大扭矩(N・m)"].apply(lambda x: None if x == '-' else float(x))

# %%
data["MaxTorque"].describe()
# Out:
# count    103782.000000
# mean        306.322943
# std         123.254933
# min          72.000000
# 25%         224.000000
# 50%         290.000000
# 75%         350.000000
# max        1200.000000
# Name: MaxTorque, dtype: float64

# %% [markdown]
# ### 发动机

# %% [markdown]
# #### 查看

# %%
data["发动机"]
# Out:
# 0         3.0T 350马力 V6
# 1         2.0T 184马力 L4
# 2         2.0T 230马力 L4
# 3         2.0T 180马力 L4
# 4         3.0T 340马力 L6
#               ...
# 104170     1.0L 71马力 L3
# 104171    1.6L 130马力 L4
# 104172    3.0T 367马力 V6
# 104173    2.0T 224马力 L4
# 104174    2.0T 184马力 L4
# Name: 发动机, Length: 104175, dtype: object

# %% [markdown]
# 发动机参数分为排量（是否涡轮增压），马力（功率），发动机气缸数量和布置形式

# %% [markdown]
# #### 分列

# %%
# 获取排量
def getDisplacement(s):
    s = s["发动机"]
    if ("增程式" in s):
        return None, None, None
    else:
        s = s.split()
    if (s[0][-1] == "T"):
        return float(s[0][:-1]), True, s[2]
    elif (s[0][-1] == "L"):
        return float(s[0][:-1]), False, s[2]
    else:
        return float(s[0][:-1]), None, s[2]

# %%
data[["Displacement", "Turbo", "Engine"]] = data.apply(getDisplacement, axis=1, result_type="expand")

# %%
# 排量
data["Displacement"].describe()
# Out:
# count    104067.000000
# mean          2.178960
# std           0.787423
# min           0.800000
# 25%           1.600000
# 50%           2.000000
# 75%           2.400000
# max           6.800000
# Name: Displacement, dtype: float64

# %%
# 是否涡轮增压
data["Turbo"].value_counts()
# Out:
# True     70114
# False    33953
# Name: Turbo, dtype: int64

# %%
# 发动机布置类型
data["Engine"].value_counts()
# Out:
# L4     76510
# V6     14277
# L3      3875
# L6      3863
# V8      3118
# H4       866
# H6       677
# V12      365
# W12      194
# L5       167
# V10      155
# Name: Engine, dtype: int64

# %% [markdown]
# ### 变速箱

# %% [markdown]
# #### 查看

# %%
data["变速箱"].value_counts()
# Out:
# 8挡手自一体                21939
# 6挡手自一体                21195
# 7挡湿式双离合               14294
# 9挡手自一体                 8165
# CVT无级变速                5466
# 7挡手自一体                 5399
# 7挡干式双离合                5074
# 5挡手动                   3015
# CVT无级变速(模拟8挡)          2973
# 6挡湿式双离合                2139
# 5挡手自一体                 1938
# E-CVT无级变速              1512
# 4挡自动                   1416
# 5挡自动                   1172
# CVT无级变速(模拟7挡)          1111
# 6挡干式双离合                1019
# 4挡手自一体                  949
# 8挡湿式双离合                 858
# 6挡手动                    762
# CVT无级变速(模拟6挡)           724
# 6挡自动                    671
# 10挡手自一体                 656
# CVT无级变速(模拟10挡)          389
# 5挡AMT                   365
# 8挡自动                    352
# 2挡自动                    161
# 电动车单速变速箱                114
# 6挡AMT                    91
# 9挡自动                     84
# E-CVT+自动变速箱（模拟10挡）       66
# 7挡ISR变速箱                 37
# AMT（组合10挡）               24
# CVT无级变速(模拟9挡)            16
# ...

# %% [markdown]
# ### 长*宽*高(mm)

# %% [markdown]
# #### 查看

# %%
data["长*宽*高(mm)"]
# Out:
# 0         5262*1948*1481
# 1         4734*1811*1455
# 2         4629*1898*1655
# 3         4761*1826*1439
# 4         4857*1902*1358
#                ...
# 104170    2695*1663*1555
# 104171    4610*1800*1450
# 104172    5466*1899*1498
# 104173    5087*1868*1500
# 104174    4734*1811*1453
# Name: 长*宽*高(mm), Length: 104175, dtype: object

# %% [markdown]
# #### 拆分

# %%
def splitSize(s):
    s = s["长*宽*高(mm)"].split("*")
    if (s[0] == "未知" or s[1] == "未知" or s[2] == "未知"):
        return None, None, None
    else:
        return float(s[0]), float(s[1]), float(s[2]),

# %%
data[["size_l", "size_w", "size_h"]] = data.apply(splitSize, axis = 1, result_type="expand")

# %%
data["size_w"].describe()
# Out:
# count    104158.000000
# mean       1852.698881
# std          74.272416
# min        1495.000000
# 25%        1810.000000
# 50%        1850.000000
# 75%        1898.000000
# max        2195.000000
# Name: size_w, dtype: float64

# %% [markdown]
# ### 车身结构

# %% [markdown]
# #### 查看

# %%
data["车身结构"]
# Out:
# 0          4门5座三厢车
# 1          4门5座三厢车
# 2          5门5座SUV
# 3          4门5座三厢车
# 4         2门4座硬顶跑车
#             ...
# 104170     3门2座两厢车
# 104171     4门5座三厢车
# 104172     4门5座三厢车
# 104173     4门5座三厢车
# 104174     4门5座三厢车
# Name: 车身结构, Length: 104175, dtype: object

# %% [markdown]
# #### 拆分

# %%
def getDoorSeat(s):
    s = s["车身结构"]
    door, seat, temp = re.split("门|座", s)
    return int(door), int(seat)

# %%
data[["Doors", "Seats"]] = data.apply(getDoorSeat, axis = 1, result_type="expand")
data
# Out:
#         Brand        Series                            CarName Province City  \
# 0        玛莎拉蒂            总裁                  总裁 2018款 3.0T 豪华版       江西   南昌
# 1          宝马          宝马3系               宝马3系 2013款 320Li 时尚型       江苏   常州
# 2          奥迪          奥迪Q5        奥迪Q5 2017款 Plus 40 TFSI 技术型       四川   成都
# 3          奥迪         奥迪A4L          奥迪A4L 2015款 35 TFSI 自动标准型       浙江   温州
# 4          宝马          宝马8系        宝马8系 2019款 840i 双门轿跑车 M运动套装       河北  石家庄
# ...       ...           ...                                ...      ...  ...
# 104170  smart  smart fortwo  smart fortwo 2015款 1.0L 52千瓦硬顶灵动版       陕西   西安
# 104171     现代            领动             领动 2016款 1.6L 自动智炫・精英型       浙江   温州
# 104172     奔驰         迈巴赫S级           迈巴赫S级 2020款 S 450 4MATIC       江苏   苏州
# 104173     宝马          宝马5系             宝马5系 2018款 528Li 上市特别版       浙江   嘉兴
# 104174     宝马          宝马3系               宝马3系 2014款 320Li 时尚型       浙江   宁波
#
# ...

# %% [markdown]
# ### NEDC综合油耗(L/100km)

# %% [markdown]
# #### 查看

# %%
data["NEDC综合油耗(L/100km)"]
# Out:
# 0         9.4
# 1         6.9
# 2         8.4
# 3           -
# 4         7.6
#          ...
# 104170    4.4
# 104171    6.1
# 104172    9.2
# 104173    6.4
# 104174    6.9
# Name: NEDC综合油耗(L/100km), Length: 104175, dtype: object

# %% [markdown]
# #### 转浮点数

# %%
data["Oil"] = data["NEDC综合油耗(L/100km)"].apply(lambda x: None if x == '-' else float(x))

# %%
data["Oil"].describe()
# Out:
# count    91488.000000
# mean         7.689808
# std          1.985006
# min          0.700000
# 25%          6.400000
# 50%          7.300000
# 75%          8.700000
# max         20.000000
# Name: Oil, dtype: float64

# %% [markdown]
# ### 另存为数据

# %%
import os
# 避免覆盖以前的数据
for i in range(1, 100):
    if not os.path.exists("../data/whole_car_{}.csv".format(i)):
        data.to_csv("../data/whole_car_{}.csv".format(i))
        break

# %% [markdown]
# ### 选取有效列

# %%
list(data.describe().columns)
# Out:
# ['Miles',
#  '二手车报价',
#  '上市时间',
#  'Brand_label',
#  'Series_label',
#  'CarName_label',
#  'Province_label',
#  'City_label',
#  'Miles_std',
#  'CarAge',
#  'CarAge_std',
#  'Price_NewCar',
#  'Price_NewCar_std',
#  'Level_label',
#  'isEV',
#  'isICE',
#  'PollutionType',
#  'MarketTime',
#  'MaxPower',
#  'MaxTorque',
#  'Displacement',
#  'size_l',
#  'size_w',
#  'size_h',
#  'Doors',
#  'Seats',
#  'Oil']

# %%
train_cols = ['Brand_label',
     'Series_label',
     'CarName_label',
     'Province_label',
     'City_label',
     'Miles_std',
     'CarAge_std',
     'Price_NewCar_std',
     'Level_label',
     'isEV',
     'isICE',
     'PollutionType',
     'MarketTime',
     'MaxPower',
     'MaxTorque',
     'Displacement',
     'size_l',
     'size_w',
     'size_h',
     'Doors',
     'Seats',
     'Oil']

# %%
target_cols = ['二手车报价']
